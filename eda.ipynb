# %%
from lunax.viz import categoric_eda,numeric_eda
from lunax.data_processing.utils import *

# %%
import pandas as pd
df_train = load_data('./example_data/regression/train.csv', 'csv')
df_test = load_data('./example_data/regression/test.csv', 'csv')

# %%
numeric_eda([df_train,df_test],['train','test'],target='Listening_Time_minutes')

# %%
categoric_eda([df_train,df_test],['train','test'],target='Listening_Time_minutes',custom_palette=["#5A8100", "#FFB400"])
